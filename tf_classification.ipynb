# %% [markdown]
# <a href="https://colab.research.google.com/github/ndevar132/demo-repo/blob/master/tf_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
from __future__ import absolute_import,  division, print_function, unicode_literals
import tensorflow as tf
import pandas as pd

CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']

train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv"
)

test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv"
)

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)

train.head()

train_y = train.pop('Species')
test_y = test.pop('Species')

train.shape

def input_fn(features, labels, training=True, batch_size=256):
  dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))
  if training:
    dataset = dataset.shuffle(1000).repeat()
  
  return dataset.batch(batch_size)

my_feature_columns = []
for key in train.keys():
  my_feature_columns.append(tf.feature_column.numeric_column(key=key))
print(my_feature_columns)

classifier = tf.estimator.DNNClassifier(
    feature_columns = my_feature_columns,
    hidden_units=[30,10],
    n_classes=3
)

classifier.train(
    input_fn=lambda: input_fn(train, train_y, training=True),
    steps=5000
)
# Out:
# [NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpz2936xte
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpz2936xte', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpz2936xte/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 2.9528546, step = 0
# INFO:tensorflow:global_step/sec: 458.857
# INFO:tensorflow:loss = 1.2200048, step = 100 (0.221 sec)
# INFO:tensorflow:global_step/sec: 622.607
# INFO:tensorflow:loss = 1.040273, step = 200 (0.161 sec)
# INFO:tensorflow:global_step/sec: 639.644
# INFO:tensorflow:loss = 0.9588283, step = 300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 651.281
# INFO:tensorflow:loss = 0.90980804, step = 400 (0.154 sec)
# INFO:tensorflow:global_step/sec: 643.912
# INFO:tensorflow:loss = 0.8645751, step = 500 (0.155 sec)
# INFO:tensorflow:global_step/sec: 624.092
# INFO:tensorflow:loss = 0.8298216, step = 600 (0.159 sec)
# INFO:tensorflow:global_step/sec: 640.221
# INFO:tensorflow:loss = 0.81543815, step = 700 (0.158 sec)
# INFO:tensorflow:global_step/sec: 606.723
# INFO:tensorflow:loss = 0.7921916, step = 800 (0.166 sec)
# INFO:tensorflow:global_step/sec: 629.404
# INFO:tensorflow:loss = 0.77783406, step = 900 (0.159 sec)
# INFO:tensorflow:global_step/sec: 625.272
# INFO:tensorflow:loss = 0.766551, step = 1000 (0.158 sec)
# INFO:tensorflow:global_step/sec: 643.169
# INFO:tensorflow:loss = 0.74662316, step = 1100 (0.158 sec)
# INFO:tensorflow:global_step/sec: 646.012
# INFO:tensorflow:loss = 0.72775424, step = 1200 (0.152 sec)
# INFO:tensorflow:global_step/sec: 610.462
# INFO:tensorflow:loss = 0.7188818, step = 1300 (0.164 sec)
# INFO:tensorflow:global_step/sec: 623.013
# INFO:tensorflow:loss = 0.6993934, step = 1400 (0.163 sec)
# INFO:tensorflow:global_step/sec: 613.19
# INFO:tensorflow:loss = 0.69366544, step = 1500 (0.162 sec)
# INFO:tensorflow:global_step/sec: 578.721
# INFO:tensorflow:loss = 0.6691092, step = 1600 (0.172 sec)
You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:global_step/sec: 671.394
# INFO:tensorflow:loss = 0.52607304, step = 3700 (0.148 sec)
# INFO:tensorflow:global_step/sec: 719.378
# INFO:tensorflow:loss = 0.5110541, step = 3800 (0.139 sec)
# INFO:tensorflow:global_step/sec: 693.874
# INFO:tensorflow:loss = 0.5092973, step = 3900 (0.146 sec)
# INFO:tensorflow:global_step/sec: 632.594
# INFO:tensorflow:loss = 0.5025817, step = 4000 (0.158 sec)
# INFO:tensorflow:global_step/sec: 680.214
# INFO:tensorflow:loss = 0.4949652, step = 4100 (0.145 sec)
# INFO:tensorflow:global_step/sec: 671.819
# INFO:tensorflow:loss = 0.49298215, step = 4200 (0.148 sec)
# INFO:tensorflow:global_step/sec: 598.21
# INFO:tensorflow:loss = 0.48509514, step = 4300 (0.169 sec)
# INFO:tensorflow:global_step/sec: 662.882
# INFO:tensorflow:loss = 0.47928655, step = 4400 (0.151 sec)
# INFO:tensorflow:global_step/sec: 699.567
# INFO:tensorflow:loss = 0.47745544, step = 4500 (0.141 sec)
# INFO:tensorflow:global_step/sec: 695.086
# INFO:tensorflow:loss = 0.47039062, step = 4600 (0.145 sec)
# INFO:tensorflow:global_step/sec: 658.692
# INFO:tensorflow:loss = 0.4694559, step = 4700 (0.153 sec)
# INFO:tensorflow:global_step/sec: 678.059
# INFO:tensorflow:loss = 0.4605234, step = 4800 (0.147 sec)
# INFO:tensorflow:global_step/sec: 672.691
# INFO:tensorflow:loss = 0.45074463, step = 4900 (0.148 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpz2936xte/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.45292526.

# %%
eval_result = classifier.evaluate(input_fn=lambda: input_fn(test, test_y, training=False))
print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-16T00:40:11Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpfk70ozrh/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18616s
# INFO:tensorflow:Finished evaluation at 2020-06-16-00:40:11
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.8333333, average_loss = 0.71062887, global_step = 5000, loss = 0.71062887
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmpfk70ozrh/model.ckpt-5000
#
# Test set accuracy: 0.833

# %%
def input_fn(features, batch_size=256):
  # convert input to dataset without labels
  return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

features = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
predict = {}

# print("please type numeric value as prompted")
# for feature in features:
#   valid = True
#   while valid:
#     val = input(feature + ": ")
#     if not val.isdigit(): valid = False
  
#   predict[feature] = [float(val)]

# predictions = classifier.predict(input_fn=lambda: input_fn(predict))

# for pred_dict in predictions:
#   class_id = pred_dict['class_ids'][0]
#   probability = pred_dict['probabilities'][class_id]

#   print('Predictions is "{}" ({:.1f}%)'.format(
#       SPECIES[class_id], 100 * probability
#   ))

expected = ['Setosa', 'Versicolor', 'Virginica']
predict_x = {
    'SepalLength': [5.1, 5.9, 6.9],
    'SepalWidth': [3.3, 3.0, 3.1],
    'PetalLength': [1.7, 4.2, 5.4],
    'PetalWidth': [.5, 1.5, 2.1]
}

predictions = classifier.predict(input_fn=lambda: input_fn(predict_x))

for pred_dict in predictions:
  class_id = pred_dict['class_ids'][0]
  probability = pred_dict['probabilities'][class_id]

  print('Predictions is "{}" ({:.1f}%)'.format(
      SPECIES[class_id], 100 * probability
))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpz2936xte/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Predictions is "Setosa" (69.0%)
# Predictions is "Versicolor" (48.7%)
# Predictions is "Virginica" (62.9%)
